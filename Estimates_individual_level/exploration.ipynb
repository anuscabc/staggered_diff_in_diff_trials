# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('workers_panel_firm_entry_exit_large.csv')
df.head()
# Out:
#    year  business_id  personal_id education_level  age  tenure  \
# 0  2010          100            1            high   49       6
# 1  2011          100            1            high   50       7
# 2  2012          100            1            high   51       8
# 3  2013          100            1            high   52       9
# 4  2014          100            1            high   53      10
#
#    firm_entry_year  firm_exit_year  first_year_treatment  treatment  \
# 0             2010            2019                  2018          0
# 1             2010            2019                  2018          0
# 2             2010            2019                  2018          0
# 3             2010            2019                  2018          0
# 4             2010            2019                  2018          0
#
#     base_income
# 0  53597.393410
# 1  54377.937394
# 2  55501.871835
# 3  56315.839251
# 4  56963.955200

# %%
sns.lineplot(
    data=df,
    x='year',
    y='base_income',
    hue='business_id',
)
plt.show()
